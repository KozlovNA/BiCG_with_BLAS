# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/BCGSTAB_logs.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_2norm_rel']
    
    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='b',alpha=0.5, label='BCGSTAB')
    
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")



# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/BBCGSTAB_logs.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_max2norm_rel']
    eps = 0.01*np.ones(len(x))
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='BBCGSTAB')
    plt.plot(x, eps, label='threshold')
    # Adding titles and labels
    plt.title('Plot of res vs k BCGSTAB vs BBCGSTAB')
    plt.xlabel('k')
    plt.ylabel('res')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %%
import numpy as np
r0 = np.array([10, 3, 3])
pk = np.array([10, 3, 3])
sk = np.array([2.5295, -7.6964, -0.735252])
alpha = 118/695 
A = np.array([[2, 3, 5],
             [3, 7, 4],
             [1, 2, 2]])
vk = A@pk
print(A@sk)
tk = A@sk
omegak = np.dot(tk, sk)/np.dot(tk,tk)
print(omegak)
x = np.array([0.0,0.0,0.0])
x += pk*alpha + omegak*sk
print(x)
rkp1 = sk-omegak*tk
print(rkp1)
beta_rhs = -np.dot(r0,tk)
print(beta_rhs)
beta = beta_rhs/695
print(beta)
# pkp1 = rkp1-(omegak*vk) * beta + pk*beta
pkp1 = rkp1 + pk*beta
print (pk + pk*beta - omegak*vk*beta + rkp1)

# %%
r2 = np.array([0, 1, 0])
rnew = np.vstack([r0, r2])
print(rnew)
print(rnew@(A@rnew.T))
