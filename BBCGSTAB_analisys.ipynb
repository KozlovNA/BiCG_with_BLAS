# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/BCGSTAB_logs_col0.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_2norm_rel']
    
    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='b',alpha=0.5, label='BCGSTAB col(0)')
    
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")
###########################
csv_file_path = './output/BCGSTAB_logs_col1.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_2norm_rel']
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='purple',alpha=0.5, label='BCGSTAB col(1)')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")    

###############################

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/BBCGSTAB_logs_leftCols2.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_max2norm_rel']
    eps = 0.01*np.ones(len(x))
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='BBCGSTAB leftCols(2)')
    plt.plot(x, eps, label='threshold')
    # Adding titles and labels
    plt.title(r'Plot of $||res||_2$ vs k BCGSTAB vs BBCGSTAB')
    plt.xlabel('k')
    plt.ylabel('res')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/BCGSTAB_logs_0.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_2norm_rel']
    
    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='b',alpha=0.5, label='BCGSTAB 0')
    
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")
###########################
csv_file_path = './output/BCGSTAB_logs_1.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_2norm_rel']
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='purple',alpha=0.5, label='BCGSTAB 120')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")    

###############################

csv_file_path = './output/BCGSTAB_logs_2.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_2norm_rel']
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='purple',alpha=0.5, label='BCGSTAB 240')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")    

###############################

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/BBCGSTABSR_logs.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_max2norm_rel']
    eps = 0.01*np.ones(len(x))
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='BBCGSTAB 0,120,240')
    plt.plot(x, eps, label='threshold')
    # Adding titles and labels
    plt.title(r'Plot of $||res||_2$ vs k BCGSTAB vs BBCGSTAB')
    plt.xlabel('k')
    plt.ylabel('res')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

bcgs_columns = np.array([180, 204, 155, 229, 130, 255, 104, 284, 75, 320, 39, 360, 0, 168, 242])
sum_k = 0
for col_name in bcgs_columns:
    csv_file_path = './output/tezisi/one_rhs/bicgstab_logs'+ str(col_name) +'.csv'
    data = pd.read_csv(csv_file_path)

    # Check if the required columns exist
    if 'k' in data.columns and 'res_2norm_rel' in data.columns:
        # Extract the columns
        x = np.array(data['k'])
        sum_k += x[-1]
        y = data['res_2norm_rel']
        plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='purple',alpha=0.05)
        plt.semilogy()
        
    else:
        print("The required columns 'k' and 'res_2norm' are not in the CSV file.")    


csv_file_path = './output/tezisi/one_rhs/bicgstab_logs'+ str(180) +'.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_2norm_rel']
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='purple',alpha=0.0, label="BiCGStab")
    plt.semilogy()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

print(sum_k)
###############################

csv_file_path = './output/bbcgsr/rrqr_361_rhs_15_picked.csv'

data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    print(x[-1]*15)
    print(x[-1]*15 / sum_k)
    y = data['res_max2norm_rel']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='b', alpha=0.5, label=r'Реортог')

###############################

csv_file_path = './output/bbcgsr/rrqr_361_rhs_15_picked_um1.csv'

data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    print(x[-1]*15)
    print(x[-1]*15 / sum_k)
    y = data['res_max2norm_rel']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='g', alpha=0.5, label=r'Реортог + $U^{-1}$')


# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
# csv_file_path = './output/tezisi/many_rhs_bicgstabregul/blbicgstabregul_log15.csv'
# csv_file_path = './output/tezisi/many_rhs_bicgstabregul/BBCGSR_logs.csv'
# csv_file_path = './output/tezisi/many_rhs_bicgstab/BBCGSTAB_logs.csv'
csv_file_path = './output/bbcgsr/rrqr_361_rhs_15_picked_phat.csv'

data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    print(x[-1]*15)
    print(x[-1]*15 / sum_k)
    y = data['res_max2norm_rel']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    eps = 0.01*np.ones(len(x))
    plt.plot(x, eps, label='threshold')
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label=r'Реортог + $\hat{P}$')
    # Adding titles and labels
    plt.title('Модифицированный Bl-BiCGStab для 15 правых частей')
    plt.xlabel('k')
    plt.ylabel(r'$max||res||_2 \; / \; max||res_0||_2 $')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")
# Out:
# 1262.5
# 1177.5
# 0.9326732673267327
# 1102.5
# 0.8732673267326733
# 1492.5
# 1.1821782178217821

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

csv_file_path = './output/tezisi/many_rhs_bicgstab/4.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    sum_k += x[-1]
    y = data['res_max2norm_rel']
    max_k = 400
    plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='blue',alpha=0.5,label="Bl-BiCGStab")
    plt.semilogy()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

###############################

# csv_file_path = './output/tezisi/many_rhs_bicgstabregul/4.csv'
csv_file_path = '/home/starman/Projects/INM/BiCG_with_BLAS/output/bbcgsr/rrqr_361_rhs_10_picked_um1_r0qr_float.csv'

data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    eps = 0.01*np.ones(400)
    plt.plot([0,200], [0.01, 0.01], label='порог')
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='модифицированный метод')
    # Adding titles and labels
    plt.title('Модифицированный Bl-BiCGStab для 4 правых частей')
    plt.xlabel('k')
    plt.ylabel(r'$max||res||_2 \; / \; max||res_0||_2 $')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.savefig("./output/bbcgsr/plots/4.pdf")
    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

bcgs_columns = np.array([180, 204, 155, 229, 130, 255, 104, 284, 75, 320])
sum_k = 0
for col_name in bcgs_columns:
    csv_file_path = './output/tezisi/one_rhs/bicgstab_logs'+ str(col_name) +'.csv'
    data = pd.read_csv(csv_file_path)

    # Check if the required columns exist
    if 'k' in data.columns and 'res_2norm_rel' in data.columns:
        # Extract the columns
        x = np.array(data['k'])
        sum_k += x[-1]
        y = data['res_2norm_rel']
        plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='purple',alpha=0.05)
        plt.semilogy()
        
    else:
        print("The required columns 'k' and 'res_2norm' are not in the CSV file.")    


csv_file_path = './output/tezisi/one_rhs/bicgstab_logs'+ str(180) +'.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_2norm_rel']
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='purple',alpha=0.0, label="BiCGStab")
    plt.semilogy()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

print(sum_k)
###############################

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
# csv_file_path = './output/tezisi/many_rhs_bicgstabregul/blbicgstabregul_log10.csv'
csv_file_path = './output/bbcgsr/rrqr_361_rhs_10_picked_um1_r0qr.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    print(x[-1]*10)
    print(x[-1]*10 / sum_k)
    y = data['res_max2norm_rel']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    eps = 0.01*np.ones(len(x))
    plt.plot(x, eps, label='threshold')
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='модифицированный метод')
    # Adding titles and labels
    plt.title('Модифицированный Bl-BiCGStab для 10 правых частей')
    plt.xlabel('k')
    plt.ylabel(r'$max||res||_2 \; / \; max||res_0||_2 $')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")
# Out:
# 838.0
# 775.0
# 0.9248210023866349

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

bcgs_columns = np.array([180, 204, 155, 229, 130, 255, 104, 284, 75, 320, 39, 360, 0, 168, 242])
sum_k = 0
for col_name in bcgs_columns:
    csv_file_path = './output/tezisi/one_rhs/bicgstab_logs'+ str(col_name) +'.csv'
    data = pd.read_csv(csv_file_path)

    # Check if the required columns exist
    if 'k' in data.columns and 'res_2norm_rel' in data.columns:
        # Extract the columns
        x = np.array(data['k'])
        sum_k += x[-1]
        y = data['res_2norm_rel']
        plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='purple',alpha=0.05)
        plt.semilogy()
        
    else:
        print("The required columns 'k' and 'res_2norm' are not in the CSV file.")    


csv_file_path = './output/tezisi/one_rhs/bicgstab_logs'+ str(180) +'.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_2norm_rel']
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='purple',alpha=0.0, label="BiCGStab")
    plt.semilogy()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

print(sum_k*2)
###############################

csv_file_path = './output/bbcgs/rrqr_361_rhs_15_picked.csv'
data = pd.read_csv(csv_file_path)

if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    print(x[-1]*15*2)
    print(x[-1]*15 / sum_k)
    y = data['res_max2norm_rel']
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='b', alpha=1, label='базовый метод')

###############################

csv_file_path = './output/bbcgsr/rrqr_361_rhs_15_picked_um1_r0qr.csv'
data = pd.read_csv(csv_file_path)

if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    print(x[-1]*15*2)
    print(x[-1]*15 / sum_k)
    y = data['res_max2norm_rel']
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=1, label='модифицированный метод')

    x_eps = np.arange(100)
    eps = 0.01*np.ones(len(x_eps))
    plt.plot(x_eps, eps, label='порог')
    # Adding titles and labels
    plt.title('Модифицированный Bl-BiCGStab для 15 правых частей')
    plt.xlabel('k')
    plt.ylabel(r'$max||res||_2 \; / \; max||res_0||_2 $')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()
    plt.savefig('./output/bbcgsr/plots/acceleration_15_rhs.pdf')
    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")
# Out:
# 2525.0
# 2535.0
# 1.003960396039604
# 2235.0
# 0.8851485148514852

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

bcgs_columns = np.array([180, 204, 155, 229, 130])
sum_k = 0
for col_name in bcgs_columns:
    csv_file_path = './output/tezisi/one_rhs/bicgstab_logs'+ str(col_name) +'.csv'
    data = pd.read_csv(csv_file_path)

    # Check if the required columns exist
    if 'k' in data.columns and 'res_2norm_rel' in data.columns:
        # Extract the columns
        x = np.array(data['k'])
        sum_k += x[-1]
        y = data['res_2norm_rel']
        plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='purple',alpha=0.05)
        plt.semilogy()
        
    else:
        print("The required columns 'k' and 'res_2norm' are not in the CSV file.")    


csv_file_path = './output/tezisi/one_rhs/bicgstab_logs'+ str(180) +'.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_2norm_rel' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['res_2norm_rel']
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='purple',alpha=0.0, label="BiCGStab")
    plt.semilogy()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

print(sum_k)
###############################

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
# csv_file_path = './output/tezisi/many_rhs_bicgstabregul/blbicgstabregul_log10.csv'
csv_file_path = './output/bbcgsr/rrqr_361_rhs_5_picked_um1_r0qr.csv'

data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    print(x[-1]*5)
    print(x[-1]*5 / sum_k)
    y = data['res_max2norm_rel']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    eps = 0.01*np.ones(len(x))
    plt.plot(x, eps, label='threshold')
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='модифицированный метод')
    # Adding titles and labels
    plt.title('Модифицированный Bl-BiCGStab для 5 правых частей')
    plt.xlabel('k')
    plt.ylabel(r'$max||res||_2 \; / \; max||res_0||_2 $')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")
# Out:
# 399.0
# 427.5
# 1.0714285714285714

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked_um1_r0qr.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    max_k = 250
    plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='red',alpha=1,label="bbcgs with um1 + r0qr")
    plt.semilogy()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

###############################

csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked_um1.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    max_k = 250
    plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='g',alpha=0.7,label="bbcgs with um1")
    plt.semilogy()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

###############################

csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked_phat.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    max_k = 250
    plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='tab:orange',alpha=0.3,label="bbcgs with phat")
    plt.semilogy()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

###############################

csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    max_k = 250
    plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='blue',alpha=0.3,label="bbcgs")
    plt.semilogy()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV.")  

###############################
csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    max_k = 250
    plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='blue',alpha=0.3,label="bbcgs")
    plt.semilogy()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

###############################

csv_file_path = './output/bbcgs/rrqr_361_rhs_20_picked.csv'

data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    eps = 0.01*np.ones(250)
    plt.plot([0,125], [0.01, 0.01], label='порог')
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.3, label='bbcgsr')
    # Adding titles and labels
    plt.title('bbsgs vs -r for 20 rhss rrqr first 361')
    plt.xlabel('k')
    plt.ylabel(r'$max||res||_2 \; / \; max||res_0||_2 $')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked_um1.csv'
# data = pd.read_csv(csv_file_path)

# # Check if the required columns exist
# if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
#     # Extract the columns
#     x = np.array(data['k'])
#     y = data['res_max2norm_rel']
#     max_k = 250
#     plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='g',alpha=0.7,label="bbcgs with um1")
#     plt.semilogy()
    
# else:
#     print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

# ###############################

# csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked_phat.csv'
# data = pd.read_csv(csv_file_path)

# # Check if the required columns exist
# if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
#     # Extract the columns
#     x = np.array(data['k'])
#     y = data['res_max2norm_rel']
#     max_k = 250
#     plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='tab:orange',alpha=0.3,label="bbcgs with phat")
#     plt.semilogy()
    
# else:
#     print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

# ###############################

# csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked.csv'
# data = pd.read_csv(csv_file_path)

# # Check if the required columns exist
# if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
#     # Extract the columns
#     x = np.array(data['k'])
#     y = data['res_max2norm_rel']
#     max_k = 250
#     plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='blue',alpha=0.3,label="bbcgs")
#     plt.semilogy()
    
# else:
#     print("The required columns 'k' and 'res_2norm' are not in the CSV.")  

# ###############################
csv_file_path = './output/bbcgsr/rrqr_361_rhs_25_picked_um1.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    max_k = 250
    plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='blue',alpha=0.5,label="s=25")
    plt.semilogy()
    
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

###############################

csv_file_path = './output/bbcgsr/rrqr_361_rhs_40_picked_um1_r0qr.csv'

data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    eps = 0.01*np.ones(250)
    plt.plot([0,125], [0.01, 0.01], label='threshold')
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='s=30')
    # Adding titles and labels
    plt.title('Реорт + Um1 vs -r for s rhss rrqr first 361')
    plt.xlabel('k')
    plt.ylabel(r'$max||res||_2 \; / \; max||res_0||_2 $')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %%
csv_file_path = './output/bbcgsr/rrqr_361_rhs_100_picked_um1_r0qr.csv'

data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    eps = 0.01*np.ones(250)
    plt.plot([0,125], [0.01, 0.01], label='порог')
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='s=100')
    # Adding titles and labels
    plt.title('Модифицированный метод')
    plt.xlabel('k')
    plt.ylabel(r'$max||res||_2 \; / \; max||res_0||_2 $')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.savefig('./output/bbcgsr/plots/100_rhs.pdf')
    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked_um1.csv'
# data = pd.read_csv(csv_file_path)

# # Check if the required columns exist
# if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
#     # Extract the columns
#     x = np.array(data['k'])
#     y = data['res_max2norm_rel']
#     max_k = 250
#     plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='g',alpha=0.7,label="bbcgs with um1")
#     plt.semilogy()
    
# else:
#     print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

# ###############################

# csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked_phat.csv'
# data = pd.read_csv(csv_file_path)

# # Check if the required columns exist
# if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
#     # Extract the columns
#     x = np.array(data['k'])
#     y = data['res_max2norm_rel']
#     max_k = 250
#     plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='tab:orange',alpha=0.3,label="bbcgs with phat")
#     plt.semilogy()
    
# else:
#     print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

# ###############################

# csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked.csv'
# data = pd.read_csv(csv_file_path)

# # Check if the required columns exist
# if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
#     # Extract the columns
#     x = np.array(data['k'])
#     y = data['res_max2norm_rel']
#     max_k = 250
#     plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='blue',alpha=0.3,label="bbcgs")
#     plt.semilogy()
    
# else:
#     print("The required columns 'k' and 'res_2norm' are not in the CSV.")  

# ###############################
# csv_file_path = './output/bbcgsr/rrqr_361_rhs_25_picked_um1.csv'
# data = pd.read_csv(csv_file_path)

# # Check if the required columns exist
# if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
#     # Extract the columns
#     x = np.array(data['k'])
#     y = data['res_max2norm_rel']
#     max_k = 250
#     plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='blue',alpha=0.3,label="s=25")
#     plt.semilogy()
    
# else:
#     print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

###############################

csv_file_path = './output/bbcgsr/rrqr_361_rhs_40_picked_um1_r0qr.csv'

data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    eps = 0.01*np.ones(250)
    plt.plot([0,125], [0.01, 0.01], label='threshold')
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.3, label='s=30')
    # Adding titles and labels
    plt.title('Реорт + Um1 + R0 vs -r for s rhss rrqr first 361')
    plt.xlabel('k')
    plt.ylabel(r'$max||res||_2 \; / \; max||res_0||_2 $')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked_um1.csv'
# data = pd.read_csv(csv_file_path)

# # Check if the required columns exist
# if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
#     # Extract the columns
#     x = np.array(data['k'])
#     y = data['res_max2norm_rel']
#     max_k = 250
#     plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='g',alpha=0.7,label="bbcgs with um1")
#     plt.semilogy()
    
# else:
#     print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

# ###############################

# csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked_phat.csv'
# data = pd.read_csv(csv_file_path)

# # Check if the required columns exist
# if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
#     # Extract the columns
#     x = np.array(data['k'])
#     y = data['res_max2norm_rel']
#     max_k = 250
#     plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='tab:orange',alpha=0.3,label="bbcgs with phat")
#     plt.semilogy()
    
# else:
#     print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

# ###############################

# csv_file_path = './output/bbcgsr/rrqr_361_rhs_20_picked.csv'
# data = pd.read_csv(csv_file_path)

# # Check if the required columns exist
# if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
#     # Extract the columns
#     x = np.array(data['k'])
#     y = data['res_max2norm_rel']
#     max_k = 250
#     plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='blue',alpha=0.3,label="bbcgs")
#     plt.semilogy()
    
# else:
#     print("The required columns 'k' and 'res_2norm' are not in the CSV.")  

# ###############################
# csv_file_path = './output/bbcgsr/rrqr_361_rhs_25_picked_um1.csv'
# data = pd.read_csv(csv_file_path)

# # Check if the required columns exist
# if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
#     # Extract the columns
#     x = np.array(data['k'])
#     y = data['res_max2norm_rel']
#     max_k = 250
#     plt.plot(x[0:max_k], y[0:max_k], marker='o', markersize=3, linestyle='-', color='blue',alpha=0.3,label="s=25")
#     plt.semilogy()
    
# else:
#     print("The required columns 'k' and 'res_2norm' are not in the CSV.")    

###############################

csv_file_path = './output/bbcgsr/rrqr_361_second_rhs_5_picked_um1_r0qr.csv'

data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'res_max2norm_rel' in data.columns:
    # Extract the columns
    x = np.array(data['k'])
    y = data['res_max2norm_rel']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    eps = 0.01*np.ones(250)
    plt.plot([0,125], [0.01, 0.01], label='threshold')
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.3, label='s=30')
    # Adding titles and labels
    plt.title('Реорт + Um1 + R0 vs -r for s rhss rrqr first 361')
    plt.xlabel('k')
    plt.ylabel(r'$max||res||_2 \; / \; max||res_0||_2 $')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %%
import numpy as np
r0 = np.array([10, 3, 3])
pk = np.array([10, 3, 3])
sk = np.array([2.5295, -7.6964, -0.735252])
alpha = 118/695 
A = np.array([[2, 3, 5],
             [3, 7, 4],
             [1, 2, 2]])
vk = A@pk
print(A@sk)
tk = A@sk
omegak = np.dot(tk, sk)/np.dot(tk,tk)
print(omegak)
x = np.array([0.0,0.0,0.0])
x += pk*alpha + omegak*sk
print(x)
rkp1 = sk-omegak*tk
print(rkp1)
beta_rhs = -np.dot(r0,tk)
print(beta_rhs)
beta = beta_rhs/695
print(beta)
# pkp1 = rkp1-(omegak*vk) * beta + pk*beta
pkp1 = rkp1 + pk*beta
print (pk + pk*beta - omegak*vk*beta + rkp1)

# %%
r2 = np.array([0, 1, 0])
rnew = np.vstack([r0, r2])
print(rnew)
print(rnew@(A@rnew.T))

# %% [markdown]
# ## rcond research

# %% [markdown]
# alpha

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/alpha_rcon_i.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'alpha_trcon1' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['alpha_trcon1']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='b', alpha=0.5, label='I-norm')
    # Adding titles and labels
    # plt.title(r'Plot of k vs rcond BBCGSR')
    # plt.xlabel('k')
    # plt.ylabel('rcond')
    # plt.semilogy()
    
    # Show grid
    # plt.grid()
    
    # Add legend
    plt.legend()

    # plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

###############################

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/alpha_rcon_1.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'alpha_trcon1' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['alpha_trcon1']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='1-norm')
    # Adding titles and labels
    plt.title(r'Plot of k vs rcond of alpha system BBCGSR')
    plt.xlabel('k')
    plt.ylabel('rcond')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %% [markdown]
# beta

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/beta_rcon_i.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'beta_trconi' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['beta_trconi']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='b', alpha=0.5, label='I-norm')
    # Adding titles and labels
    # plt.title(r'Plot of k vs rcond BBCGSR')
    # plt.xlabel('k')
    # plt.ylabel('rcond')
    # plt.semilogy()
    
    # Show grid
    # plt.grid()
    
    # Add legend
    plt.legend()

    # plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

###############################

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/beta_rcon_1.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'beta_trcon1' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['beta_trcon1']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='1-norm')
    # Adding titles and labels
    plt.title(r'Plot of k vs rcond of beta system BBCGSR')
    plt.xlabel('k')
    plt.ylabel('rcond')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/PhatPk_gecon_i.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'gecon' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['gecon']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='b', alpha=0.5, label='I-norm')
    # Adding titles and labels
    # plt.title(r'Plot of k vs rcond BBCGSR')
    # plt.xlabel('k')
    # plt.ylabel('rcond')
    # plt.semilogy()
    
    # Show grid
    # plt.grid()
    
    # Add legend
    plt.legend()

    # plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

###############################

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/PhatPk_gecon_1.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'gecon' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['gecon']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='1-norm')
    # Adding titles and labels
    plt.title(r'Plot of k vs rcond of $\hat{P}^*_0P_k$ system BBCGSR')
    plt.xlabel('k')
    plt.ylabel('rcond')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/omega_module.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'module' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['module']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='b', alpha=0.5, label='abs value * frob norm T_k')
    # Adding titles and labels
    # plt.title(r'Plot of k vs rcond BBCGSR')
    # plt.xlabel('k')
    # plt.ylabel('rcond')
    # plt.semilogy()
    
    # Show grid
    # plt.grid()
    
    # Add legend
    plt.legend()

    # plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

###############################

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/omega_real.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
if 'k' in data.columns and 'real' in data.columns:
    # Extract the columns
    x = data['k']
    y = data['real']
    # Create the plot
    # plt.figure(figsize=(10, 6))
    plt.plot(x, np.abs(y), marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='abs of real part')
    # Adding titles and labels
    plt.title(r'Plot of k vs real part and $|omega| * ||T_k||_F$ of $\omega$ system BBCGSR')
    plt.xlabel('k')
    plt.ylabel('rcond')
    plt.semilogy()
    
    # Show grid
    plt.grid()
    
    # Add legend
    plt.legend()

    plt.show()
    # Show the plot
else:
    print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

# %% [markdown]
# Минимальное сингулярное число блока невязок $R_k$

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/R_nrmminsv.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
# if 'k' in data.columns and 'v' in data.columns:
# Extract the columns
x = data['k']
y = data['v']
# Create the plot
# plt.figure(figsize=(10, 6))
plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='b', alpha=0.5)
# Adding titles and labels
# plt.title(r'Plot of k vs rcond BBCGSR')
# plt.xlabel('k')
# plt.ylabel('rcond')
# plt.semilogy()

# Show grid
# plt.grid()

# Add legend
plt.legend()

# plt.show()
# Show the plot
# else:
# print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

###############################

# Adding titles and labels
plt.title(r'Plot of k vs minimal singular value of $R_k$ BBCGSR')
plt.xlabel('k')
plt.ylabel('minsv')
plt.semilogy()

# Show grid
plt.grid()

# Add legend
plt.legend()

plt.show()
# Show the plot
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/P_nrmsv.csv'
data = pd.read_csv(csv_file_path)

# Check if the required columns exist
# if 'k' in data.columns and 'min' in data.columns:
# Extract the columns
x = data['k']
y_min = data['min']
# Create the plot
# plt.figure(figsize=(10, 6))
# plt.plot(x, y, marker='o', markersize=3, linestyle='-', color='b', alpha=0.5, label='abs value * frob norm T_k')
# Adding titles and labels
# plt.title(r'Plot of k vs rcond BBCGSR')
# plt.xlabel('k')
# plt.ylabel('rcond')
# plt.semilogy()

# Show grid
# plt.grid()

# Add legend
# plt.legend()

# plt.show()
# Show the plot
# else:
# print("The required columns 'k' and 'res_2norm' are not in the CSV file.")

###############################

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file

# Check if the required columns exist
# if 'k' in data.columns and 'real' in data.columns:
# Extract the columns
# x = data['k']
y_max = data['max']
# Create the plot
# plt.figure(figsize=(10, 6))
plt.plot(x, np.abs(y_min/y_max), marker='o', markersize=3, linestyle='-', color='r', alpha=0.5)
# Adding titles and labels
plt.title(r'Plot of k vs $\frac{\sigma_{min}}{\sigma_{max}}$ for $P_k$ with normalized columns BBCGSR')
plt.xlabel('k')
plt.ylabel(r'$\frac{\sigma_{min}}{\sigma_{max}}$')
plt.semilogy()

# Show grid
plt.grid()

# Add legend
plt.legend()

plt.show()
# Show the plot
# else:
    # print("The required columns 'k' and 'res_2norm' are not in the CSV file.")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/P_nrmsv.csv'
data = pd.read_csv(csv_file_path)
if (1):
    x = data['k']
    y_min = data['min']
    y_max = data['max']

    plt.plot(x, np.abs(y_min/y_max), marker='o', markersize=3, linestyle='-', color='b', alpha=0.5, label='P_k')


###############################

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/Phat_nrmsv.csv'
data = pd.read_csv(csv_file_path)

if(1):
    x = data['k']
    y_min = data['min']
    y_max = data['max']
    plt.plot(x, np.abs(y_min/y_max), marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='P_k (Phat P_0^*  P_k)^{-1}')
plt.title(r'Plot of k vs $\frac{\sigma_{min}}{\sigma_{max}}$ for $P_k$ with normalized columns BBCGSR')
plt.xlabel('k')
plt.ylabel(r'$\frac{\sigma_{min}}{\sigma_{max}}$')
plt.semilogy()

# Show grid
plt.grid()

# Add legend
plt.legend()

plt.show()
# Show the plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
csv_file_path = './output/R_nrmminsv.csv'
data = pd.read_csv(csv_file_path)
x = data['k']
y_min = data['v']

plt.plot(x, y_min, marker='o', markersize=3, linestyle='-', color='b', alpha=0.5, label='min')


###############################

csv_file_path = './output/R_nrmmaxsv.csv'
data = pd.read_csv(csv_file_path)

x = data['k']
y_max = data['v']
plt.plot(x, y_max, marker='o', markersize=3, linestyle='-', color='r', alpha=0.5, label='max')
plt.title(r'Plot of k vs $\sigma_{min}$ and$\sigma_{max}$ for $R_k$ BBCGSR')
plt.xlabel('k')
plt.ylabel(r'value')
plt.semilogy()

# Show grid
plt.grid()

# Add legend
plt.legend()

plt.show()
# Show the plot
